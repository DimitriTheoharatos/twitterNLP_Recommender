# %%
import tweepy
import cnfg
from tqdm import tqdm

import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
config = cnfg.load(".twitter_config")

auth = tweepy.OAuthHandler(config["consumer_key"],
                           config["consumer_secret"])
auth.set_access_token(config["access_token"],
                      config["access_token_secret"])

api=tweepy.API(auth)

# %%
tweet_dict_list = []

for t in tqdm(tweets):
    d = {}
    d['created_at'] = t.created_at
    d['favorite_count'] = t.favorite_count
    d['retweet_count'] = t.retweet_count
    d['full_text'] = t.full_text
    d['screen_name'] = t.user.screen_name
    
    tweet_dict_list.append(d)
# Out:
# 10it [00:00, 21.85it/s]

# %%
tweet_dict_list[0]
# Out:
# {'full_text': 'We are mobilizing to support those impacted by the #CampFire, #HillFire and #WoolseyFire with SOS Alerts, and committing resources from @googleorg to aid those in need. Our thoughts are with all those displaced by these fires.',
#  'screen_name': 'sundarpichai'}

# %%
username = 'NLPbotz'

# %%
friends = tweepy.Cursor(api.friends, screen_name = username).items()

# %%
friend_info = []
for friend in friends:
    d = {}
    d['name'] = friend.name
    d['handle'] = friend.screen_name
    friend_info.append(d)

# %%
friends_df = pd.DataFrame(friend_info)

# %%
friends_df.head()
# Out:
#           handle                name
# 0   sundarpichai       Sundar Pichai
# 1  SenGillibrand  Kirsten Gillibrand
# 2    ericschmidt        Eric Schmidt
# 3    VentureBeat         VentureBeat
# 4      sfstation          SF Station

# %%
tweet_dict_list = []
for user in friends_df.handle:

    print(user)
    time.sleep(1)
    try:
        tweets = tweepy.Cursor(api.user_timeline,\
                       screen_name=user, tweet_mode='extended').items()
    
        for t in tqdm(tweets):
            d = {}
            d['full_text'] = t.full_text
            d['screen_name'] = t.user.screen_name
        
            tweet_dict_list.append(d)
    except:
        print('Pausing for 15 mins:')
        time.sleep(1000)
# Out:
# BarackObama
# 0it [00:00, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1it [00:00,  2.61it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 21it [00:00,  3.70it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 41it [00:00,  5.22it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 61it [00:00,  7.36it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 81it [00:00, 10.34it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 101it [00:01, 14.17it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 121it [00:01, 19.59it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 141it [00:01, 26.51it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 161it [00:01, 35.58it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 181it [00:01, 47.18it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 221it [00:01, 61.90it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 261it [00:01, 77.69it/s]
#
#
#
#
#
#
#
#
#
#
#
# ...

# %%
tweets_df = pd.DataFrame(tweet_dict_list)
tweets_df.drop_duplicates(inplace=True)
tweets_df.to_csv('tweets.csv')
